# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_14-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-15
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_16-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-17
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-18
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-19
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-20
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-21
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_22-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-23
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-24
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-25
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-26
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_27-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-28
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-29
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-30
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-31
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-32
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-33
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-34
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-35
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-36
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_37-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_38-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-39
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-40
# http://www.fox.com/the-following/
# #cite_ref-41
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-42
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-43
# http://baconbros.com/
# #cite_ref-44
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-45
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-46
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-47
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-48
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-49
# http://www.sixdegrees.org/
# #cite_ref-50
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-51
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-52
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-53
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-54
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-55
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-56
# #cite_ref-57
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_58-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-59
# #cite_ref-60
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-61
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-62
# http://www.drawtheline.org/sign-now/
# #cite_ref-63
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-64
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-65
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-66
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-67
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-68
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-71
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-72
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# http://id.worldcat.org/fast/242183/
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://d-nb.info/gnd/124109659
# https://id.loc.gov/authorities/n88034930
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://nla.gov.au/anbd.aut-an36021861
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# http://data.bibliotheken.nl/id/thes/p147880998
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://lod.nl.go.kr/resource/KAC2020K8226
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://cantic.bnc.cat/registre/981061093903206706
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://www.idref.fr/067287832
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1244769932
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# //wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now().strftime('%s'))
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Desert_Storm
# /wiki/Iraqi%E2%80%93Kurdish_conflict
# /wiki/Arab_Revolt
# /wiki/Battle_of_Passchendaele
# /wiki/World_War_I
# /wiki/Ante_Trumbi%C4%87
# /wiki/The_Manchester_Guardian
# /wiki/C._L._R._James
# /wiki/Wayback_Machine
# /wiki/Open_Content_Alliance
# /wiki/William_and_Flora_Hewlett_Foundation
# /wiki/OECD
# /wiki/France
# /wiki/African_Union
# /wiki/Emblem_of_the_African_Union
# /wiki/African_Investment_Bank
# /wiki/African_Union_Passport
# /wiki/Swedish_passport
# /wiki/Solomon_Islands_passport
# /wiki/Malaysian_passport
# /wiki/Visa_requirements_for_Malaysian_citizens
# /wiki/Pound_sterling
# /wiki/Central_bank
# /wiki/ISSN_(identifier)
# /wiki/ISO_216
# /wiki/Paper_density
# /wiki/Inkjet_paper
# /wiki/Bible_paper
# /wiki/Tissue_paper
# /wiki/Sumatra
# /wiki/Binjai
# /wiki/Makassar
# /wiki/Pekanbaru
# /wiki/Kupang
# /wiki/Palembang
# /wiki/Barisan_Mountains
# /wiki/Volcano
# /wiki/S2CID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/List_of_academic_databases_and_search_engines
# /wiki/Grant_(money)
# /wiki/Scottish_Government
# /wiki/Executive_agencies_of_the_Scottish_Government
# /wiki/Member_of_the_Scottish_Parliament
# /wiki/5th_Scottish_Parliament
# /wiki/Scottish_National_Party
# /wiki/Aberdeenshire_East
# /wiki/Kirkcaldy_(Scottish_Parliament_constituency)
# /wiki/UK_Independence_Party
# /wiki/Theresa_May
# /wiki/2011_England_riots
# /wiki/Battle_of_Bossenden_Wood
# /wiki/1981_Brixton_riot
# /wiki/Revolt_of_the_housewives
# /wiki/Aldershot_riot_(1945)
# /wiki/Criminal_Justice_and_Public_Order_Act_1994
# /wiki/Edwina_Currie
# /wiki/1983_United_Kingdom_general_election
# /wiki/2014_United_Kingdom_local_elections
# /wiki/2014_Southend-on-Sea_Borough_Council_election
# /wiki/Directly_elected_mayors_in_England_and_Wales
# /wiki/Referendums_in_the_United_Kingdom
# /wiki/1931_United_Kingdom_general_election
# /wiki/Manchester_Withington_(UK_Parliament_constituency)
# /wiki/Labour_Party_(UK)
# /wiki/Shadow_Cabinet_of_Jeremy_Corbyn
# /wiki/2017_United_Kingdom_general_election
# /wiki/The_Skwawkbox
# /wiki/English_defamation_law
# /wiki/Command_paper
# /wiki/Treaty_series
# /wiki/Senate_Document
# /wiki/64th_Congress
# /wiki/Independent_Party_(United_States)
# /wiki/C._G._E._Mannerheim
# /wiki/United_Kingdom
# /wiki/Defence_Council_of_the_United_Kingdom
# /wiki/Navy_Command_(Ministry_of_Defence)
# /wiki/Royal_Navy_Surface_Fleet
# /wiki/Type_45_destroyer
# /wiki/Type_42_destroyer
# /wiki/HMS_Glasgow_(D88)
# /wiki/HMNB_Portsmouth
# /wiki/HMNB_Devonport
# /wiki/HMS_Forward_(1984_shore_establishment)
# /wiki/Malta_Dockyard
# /wiki/United_Kingdom
# /wiki/English_Lowlands_beech_forests
# /wiki/Base-rich_soil
# /wiki/Organism
# /wiki/Doi_(identifier)
# /wiki/ISO_259
# /wiki/MPEG-7
# /wiki/Dynamic_Resolution_Adaptation
# /wiki/Motion_JPEG_2000
# /wiki/ISO_10303-28
# /wiki/ISO_2921
# /wiki/POSIX
# /wiki/SDMX
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/PHIGS
# /wiki/IEC_60364
# /wiki/Open_Data_Protocol
# /wiki/List_%26_Label
# /wiki/OLE_DB
# /wiki/Data
# /wiki/Survival_analysis
# /wiki/Jurimetrics
# /wiki/Anarchist_law
# /wiki/Freethought
# /wiki/Dual_Power
# /wiki/Communization
# /wiki/Relations_of_production
# /wiki/Perry_Anderson
# /wiki/Adam_Ulam
# /wiki/Cambridge,_Massachusetts
# /wiki/BBN_Technologies
# /wiki/Richard_Bolt
# /wiki/John_F._Kennedy
# /wiki/Nathaniel_Silsbee
# /wiki/Harrison_Henry_Atwood
# /wiki/Henry_Dearborn
# /wiki/James_Brown_Clay
# /wiki/William_Tapley_Bennett_Jr.
# /wiki/Seattle,_Washington
# /wiki/Index_of_Washington_(state)-related_articles
# /wiki/History_of_Washington_(state)
# /wiki/John_Rankin_Rogers
# /wiki/Alvan_Flanders
# /wiki/William_Pickering_(governor)
# /wiki/Henry_McBride_(politician)
# /wiki/Monrad_Wallgren
# /wiki/73rd_United_States_Congress
# /wiki/Thomas_H._Cullen
# /wiki/Stephen_A._Rudd
# /wiki/Philip_A._Goodwin
# /wiki/Richard_J._Tonry
# /wiki/Martin_J._Kennedy
# /wiki/James_Wolcott_Wadsworth_Jr.
# /wiki/Bert_Lord
# /wiki/Hamilton_Fish_III
# /wiki/List_of_United_States_senators_from_New_York
# /wiki/DeWitt_Clinton
# /wiki/Philetus_Swift
# /wiki/John_Tayler
# /wiki/Warren_M._Anderson
# /wiki/Malcolm_Smith_(U.S._politician)
# /wiki/Sean_Bell_shooting_incident
# /wiki/Death_of_Michael_Stewart
# /wiki/ISSN_(identifier)
# /wiki/International_Standard_Musical_Work_Code
# /wiki/MPEG-D
# /wiki/ISO/IEC_18014
# /wiki/Document_Style_Semantics_and_Specification_Language
# /wiki/ISO/IEC_27001
# /wiki/On-board_diagnostics
# /wiki/General_Motors
# /wiki/Suzuki
# /wiki/2018_Moto3_World_Championship
# /wiki/Netherlands
# /wiki/Francia
# /wiki/Teutons
# /wiki/Firaesi
# /wiki/Gothic_alphabet
# /wiki/Labialization
# /wiki/Athabaskan_languages
# /wiki/Ahtna_language
# /wiki/Tsetsaut_language
# /wiki/Sekani_language
# /wiki/Lateral_consonant
# /wiki/Dental_consonant
# /wiki/Voiced_retroflex_click
# /wiki/Voice_(phonetics)
# /wiki/Affricate
# /wiki/Voiceless_velar_implosive
# /wiki/Velarization
# /wiki/Scottish_Gaelic
# /wiki/Canadian_Gaelic
# /wiki/Dark_l
# /wiki/Eastern_Armenian
# /wiki/Nasal_consonant
# /wiki/Voiced_retroflex_lateral_affricate
# /wiki/Consonant
# /wiki/Geminate
# /wiki/Western_Romance
# /wiki/Portuguese_dialects
# /wiki/Voiced_labiodental_fricative
# /wiki/Mid_front_rounded_vowel
# /wiki/Alveolar_ejective_affricate
# /wiki/Place_of_articulation
# /wiki/Voiced_labial%E2%80%93alveolar_nasal
# /wiki/Voiceless_palatal_plosive
# /wiki/Palatal_ejective_stop
# /wiki/Voiceless_uvular_fricative
# /wiki/Palatal_consonant
# /wiki/Velar_lateral_ejective_affricate
# /wiki/Voiced_palatal_click
# /wiki/Voiceless_alveolar_lateral_flap
# /wiki/Voiced_palatal_implosive
# /wiki/Voiced_velar_affricate
# /wiki/Close-mid_central_unrounded_vowel
# /wiki/Epiglottal_ejective
# /wiki/Postalveolar_consonant
# /wiki/Retroflex_consonant
# /wiki/Nasal_click
# /wiki/Voiced_alveolar_approximant
# /wiki/Vietnamese_alphabet
# /wiki/Thaana
# /wiki/Woleai_script
# /wiki/List_of_writing_systems
# /wiki/Southeast_Asia
# /wiki/Laos
# /wiki/PMC_(identifier)
# /wiki/Telenursing
# /wiki/Hyperbaric_nursing
# /wiki/Inner_ear_decompression_sickness
# /wiki/Deep-water_blackout
# /wiki/Henry_Way_Kendall
# /wiki/Sheck_Exley
# /wiki/Underwater_vision
# /wiki/Hawaiian_sling
# /wiki/Marine_construction
# /wiki/Mark_Ellyatt
# /wiki/Divemaster
# /wiki/SP-350_Denise
# /wiki/Hans_Hass
# /wiki/Underwater_Offence_(Turkish_Armed_Forces)
# /wiki/Lockout%E2%80%93tagout
# /wiki/Jeanette_Epps
# /wiki/Dry_Combat_Submersible
# /wiki/Hypercapnia
# /wiki/Decompression_tables
# /wiki/ABISMO
# /wiki/Hans_Hass_Award
# /wiki/F%C3%A9d%C3%A9ration_Fran%C3%A7aise_d%27%C3%89tudes_et_de_Sports_Sous-Marins
# /wiki/Situation_awareness
# /wiki/Regulator_freeze
# /wiki/John_R._Clarke_(scientist)
# /wiki/Drowning
# /wiki/Breathing_performance_of_regulators
# /wiki/Necker_Nymph
# /wiki/Ice_diving
# /wiki/Suunto
# /wiki/Graham_Balcombe
# /wiki/Heckler_%26_Koch_P11
# /wiki/Jackstay
# /wiki/Chamber_operator
# /wiki/Cave_diving
# /wiki/Somerset
# /wiki/Chew_Stoke
# /wiki/Milestone
# /wiki/Mile-log#Distance-based_numbers
# /wiki/Manitoba
# /wiki/Canadian_heraldry
# /wiki/Coat_of_Arms_of_Nova_Scotia
# /wiki/British_monarchy
# /wiki/Prime_Minister_of_Sweden
# /wiki/Prime_Minister_of_Guinea-Bissau
# /wiki/Prime_Minister_of_Egypt
# /wiki/Waste_management_in_Egypt
# /wiki/History_of_Alexandria
# /wiki/Heracleion
# /wiki/Geographic_coordinate_system
# /wiki/85th_meridian_west
# /wiki/Caribbean_Sea
# /wiki/Syringodium_filiforme
# /wiki/Seagrass
# /wiki/Recruitment_(biology)
# /wiki/Herbivore
# /wiki/Vegetarianism
# /wiki/Environmental_movement
# /wiki/Indian_Forest_Service
# /wiki/Pratyaya_Amrit
# /wiki/Hari_Singh
# /wiki/Republic_of_India
# /wiki/ISBN_(identifier)
# /wiki/Flowchart
# /wiki/ISO_4157
# /wiki/ISO_28000
# /wiki/ISO/IEC_4909
# /wiki/ISO/IEC_10967
# /wiki/Pinyin
# /wiki/ISO_2852
# /wiki/ISO/IEC_646
# /wiki/IBM
# /wiki/IBM_Watson
# /wiki/Cynefin_framework
# /wiki/Theory_of_constraints
# /wiki/Glass_art
# /wiki/%C3%89b%C3%A9niste
# /wiki/Chinese_paper_cutting
# /wiki/Straw_marquetry
# /wiki/Metalworking
# /wiki/Stone_mould
# /wiki/Coventry
# /wiki/Challenge_Cup_(UK_ice_hockey)
# /wiki/North_Ayrshire_Wild
# /wiki/Glasgow_Clan
# /wiki/Czech_Extraliga
# /wiki/1999%E2%80%932000_Czech_Extraliga_season
# /wiki/HC_Dukla_Jihlava
# /wiki/1983%E2%80%9384_IIHF_European_Cup
# /wiki/1993_IIHF_European_Cup
# /wiki/2013_European_Trophy
# /wiki/Germany
# /wiki/Teutons
# /wiki/Anglo-Saxons
# /wiki/Corpus_Christi_College,_Cambridge
# /wiki/Wolfson_College,_Cambridge
# /wiki/Senate_House,_Cambridge
# /wiki/Queens%27_College,_Cambridge
# /wiki/Varsity_(Cambridge)
# /wiki/Factory_Records
# /wiki/Colin_Sharp
# /wiki/New_wave_music
# /wiki/Mashup_(music)
# /wiki/Plot_device
# /wiki/Freytag%27s_Pyramid
# /wiki/Persian_culture
# /wiki/Doi_(identifier)
# /wiki/Dynamic_Adaptive_Streaming_over_HTTP
# /wiki/Microsoft
# /wiki/Microsoft_Mobile
# /wiki/Paavo_Rantanen
# /wiki/Jyv%C3%A4skyl%C3%A4
# /wiki/Association_football
# /wiki/Handball
# /wiki/Ordrup
# /wiki/Bellevue_Teatret
# /wiki/Bremen_Teater_(Copenhagen)
# /wiki/Bodil_Awards
# /wiki/69th_Bodil_Awards
# /wiki/4th_Bodil_Awards
# /wiki/69th_Bodil_Awards
# /wiki/60th_Bodil_Awards
# /wiki/Bodil_Awards
# /wiki/Bodil_Award_for_Best_Danish_Film
# /wiki/AFR_(film)
# /wiki/Pia_Kj%C3%A6rsgaard
# /wiki/Mattias_Tesfaye
# /wiki/Alex_Ahrendtsen
# /wiki/Peter_Have
# /wiki/Member_of_the_Folketing
# /wiki/List_of_members_of_the_Folketing,_1987%E2%80%931988
# /wiki/Social_Democrats_(Denmark)
# /wiki/Christian_Democrats_(Denmark)
# /wiki/Liberal_Alliance_(Denmark)
# /wiki/Pernille_Vermund
# /wiki/OCLC_(identifier)
# /wiki/World_Wide_Web_Consortium
# /wiki/CSS_animations
# /wiki/Lists_of_animated_television_series
# /wiki/Ink-wash_animation
# /wiki/Market_economy
# /wiki/Fictitious_capital
# /wiki/Ordoliberalism
# /wiki/Doi_(identifier)
# /wiki/ISO_19011
# /wiki/OCR-B
# /wiki/OSI_model
# /wiki/Communication_protocol
# /wiki/IEEE_802.3
# /wiki/40GBASE-T
# /wiki/Data_signaling_rate
# /wiki/Transmission_(telecommunications)
# /wiki/Information_revolution
# /wiki/Academic_journal
# /wiki/Scientific_journal#Cost
# /wiki/Ingelfinger_rule
# /wiki/ISBN_(identifier)
# /wiki/ISO_19092-1
# /wiki/Magnetic_ink_character_recognition
# /wiki/ISO_5427
# /wiki/RM-ODP
# /wiki/4%2B1
# /wiki/Class_diagram
# /wiki/UXF
# /wiki/Object_(computer_science)
# /wiki/Bottom_type
# /wiki/Bit_array
# /wiki/Variable-length_code
# /wiki/LEB128
# /wiki/Variable-length_quantity
# /wiki/Sign_bit
# /wiki/Bit
# /wiki/Kind_(type_theory)
# /wiki/Variable_(computer_science)
# /wiki/Source_code
# /wiki/Programmer_productivity
# /wiki/OCLC_(identifier)
# /wiki/College_%26_Research_Libraries_News
# /wiki/ALA_Best_Fiction_for_Young_Adults
# /wiki/Houghton_Mifflin_Harcourt
# /wiki/Seabury_Press
# /wiki/A_Return_to_Love
# /wiki/Retrocognition
# /wiki/Table-turning
# /wiki/Remote_viewing
# /wiki/Skepticism
# /wiki/Radical_skepticism
# /wiki/Belief
# /wiki/Ainu_people#Religion
# /wiki/National_Diet
# /wiki/Japan%E2%80%93Sweden_relations
# /wiki/Holy_See%E2%80%93Japan_relations
# /wiki/Japan%E2%80%93Sweden_relations
# /wiki/Cambodia%E2%80%93Japan_relations
# /wiki/Japan%E2%80%93Saudi_Arabia_relations
# /wiki/Sakhalin
# /wiki/Sakhalin_Shipping_Company
# /wiki/Vostochny_Port
# /wiki/Port_of_Taman
# /wiki/Port_of_Sevastopol
# /wiki/Dnipropetrovsk_River_Port
# /wiki/Port_of_Izmail
# /wiki/Mykolaiv_River_Port
# /wiki/Chernihiv_River_Port
# /wiki/Ownership
# /wiki/Trademark
# /wiki/Article_6ter
# /wiki/Trademark
# /wiki/Community_Trade_Mark
# /wiki/Traditional_speciality_guaranteed
# /wiki/Appellation_d%27origine_contr%C3%B4l%C3%A9e
# /wiki/List_of_Appellation_d%27Origine_Contr%C3%B4l%C3%A9e_cheeses
# /wiki/List_of_American_cheeses
# /wiki/Parmigiano-Reggiano#American_generic_parmesan_cheese
# /wiki/Auricchio
# /wiki/Prodotto_agroalimentare_tradizionale
# /wiki/List_of_Italian_DOP_cheeses
# /wiki/Calabrian_wine
# /wiki/Calabria
# /wiki/History_of_Italian_fashion
# /wiki/Latins_(Italic_tribe)
# /wiki/PMC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO_31-9
# /wiki/ISO_15926_WIP
# /wiki/ISO_3864
# /wiki/ISO/IEC_21827
# /wiki/IEC_62304
# /wiki/ISO/IEC_9126
# /wiki/MicroPDF417
# /wiki/MPEG-4_Part_2
# /wiki/Comparison_of_video_codecs
# /wiki/Adaptive_coding
# /wiki/FM-index
# /wiki/Code-excited_linear_prediction
# /wiki/Hutter_Prize
# /wiki/Video_compression_picture_types
# /wiki/Brotli
# /wiki/Grammar-based_code
# /wiki/Average_bitrate
# /wiki/Dynamic_range
# /wiki/Power_(physics)
# /wiki/Statistical_mechanics
# /wiki/BBGKY_hierarchy
# /wiki/Shannon_entropy
# /wiki/Linear_predictive_coding
# /wiki/Run-length_encoding
# /wiki/Apple_Lossless_Audio_Codec
# /wiki/IPad_Air
# /wiki/Apple_S7
# /wiki/Cadence_Design_Systems
# /wiki/Pinduoduo
# /wiki/Public_company
# /wiki/European_corporate_law
# /wiki/Kamer_van_Koophandel_v_Inspire_Art_Ltd
# /wiki/Cartesio_Oktat%C3%B3_%C3%A9s_Szolg%C3%A1ltat%C3%B3_bt
# /wiki/Liggett_v._Lee
# /wiki/The_Modern_Corporation_and_Private_Property
# /wiki/Limited_liability
# /wiki/List_of_corporate_scandals
# /wiki/Overend,_Gurney_%26_Co
# /wiki/Panic_of_1866
# /wiki/2014_Brazilian_economic_crisis
# /wiki/Japan
# /wiki/Taoism_in_Japan
# /wiki/Chen_Tuan
# /wiki/Taoist_schools
# /wiki/East_Asian_religion
# /wiki/Lists_of_deities
# /wiki/Polynesian_mythology
# /wiki/Literature_of_Fiji
# /wiki/Fijian_dollar
# /wiki/Guam
# /wiki/Cura%C3%A7ao#History
# /wiki/Caribbean_Free_Trade_Association
# /wiki/Amazon_Cooperation_Treaty_Organization
# /wiki/Forum_for_the_Progress_and_Integration_of_South_America
# /wiki/Central_America-4_passport
# /wiki/Initiative_for_the_Integration_of_the_Regional_Infrastructure_of_South_America
# /wiki/Paraguay
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 17
#      15 newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16 print(newArticle)
# ---> 17 links = getLinks(newArticle)
#
# Cell In[3], line 10, in getLinks(articleUrl)
#       8 def getLinks(articleUrl):
#       9     html = urlopen(f'http://en.wikipedia.org{articleUrl}')
# ---> 10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~/.local/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File /usr/lib/python3.10/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File /usr/lib/python3.10/html/parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File /usr/lib/python3.10/html/parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File ~/.local/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:154, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     152 #print("START", name)
#     153 sourceline, sourcepos = self.getpos()
# --> 154 tag = self.soup.handle_starttag(
#     155     name, None, None, attr_dict, sourceline=sourceline,
#     156     sourcepos=sourcepos
#     157 )
#     158 if tag and tag.is_empty_element and handle_empty_element:
#     159     # Unlike other parsers, html.parser doesn't send separate end tag
#     160     # events for empty-element tags. (It's handled in
#    (...)
#     166     # don't want handle_endtag() to cross off any previous end
#     167     # events for tags of this name.
#     168     self.handle_endtag(name, check_already_closed=False)
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:714, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     696 """Called by the tree builder when a new tag is encountered.
#     697
#     698 :param name: Name of the tag.
#    (...)
#     711 don't call handle_endtag.
#     712 """
#     713 # print("Start tag %s: %s" % (name, attrs))
# --> 714 self.endData()
#     716 if (self.parse_only and len(self.tagStack) <= 1
#     717     and (self.parse_only.text
#     718          or not self.parse_only.search_tag(name, attrs))):
#     719     return None
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:589, in BeautifulSoup.endData(self, containerClass)
#     586     return
#     588 containerClass = self.string_container(containerClass)
# --> 589 o = containerClass(current_data)
#     590 self.object_was_parsed(o)
#
# File ~/.local/lib/python3.10/site-packages/bs4/element.py:946, in NavigableString.__new__(cls, value)
#     944 else:
#     945     u = str.__new__(cls, value, DEFAULT_OUTPUT_ENCODING)
# --> 946 u.setup()
#     947 return u
#
# File ~/.local/lib/python3.10/site-packages/bs4/element.py:183, in PageElement.setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     180     self.previous_element.next_element = self
#     182 self.next_element = next_element
# --> 183 if self.next_element is not None:
#     184     self.next_element.previous_element = self
#     186 self.next_sibling = next_sibling
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    try:
        html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    except HTTPError as e:
        print(f'HTTP Error: {e.code} - {e.reason}')
        return
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p><b><a href="/wiki/September_1964_South_Vietnamese_coup_attempt" title="September 1964 South Vietnamese coup attempt">An attempted coup took place</a></b> on September 13, 1964, in <a href="/wiki/South_Vietnam" title="South Vietnam">South Vietnam</a> against the <a href="/wiki/Army_of_the_Republic_of_Vietnam" title="Army of the Republic of Vietnam">ruling military junta</a>, led by <a href="/wiki/Nguy%E1%BB%85n_Kh%C3%A1nh" title="Nguyễn Khánh">Nguyễn Khánh</a> <i>(pictured)</i>. In the preceding month, Khánh had tried to improve his leadership by declaring a state of emergency, provoking protests and riots. He made concessions to the protesters and removed military officials linked to former President <a href="/wiki/Ngo_Dinh_Diem" title="Ngo Dinh Diem">Ngo Dinh Diem</a>, including <a href="/wiki/L%C3%A2m_V%C4%83n_Ph%C3%A1t" title="Lâm Văn Phát">Lâm Văn Phát</a> and <a href="/wiki/D%C6%B0%C6%A1ng_V%C4%83n_%C4%90%E1%BB%A9c" title="Dương Văn Đức">Dương Văn Đức</a>. They responded with a coup, broadcasting their promise to revive Diem's policies. Khánh evaded capture and rallied allies while the U.S. continued their support for his rule. Khánh forced Phát and Đức to capitulate the next morning and various coup leaders appeared at a media conference where they denied that a coup had taken place. To maintain power, Khánh tried to court support from Buddhist activists, who supported negotiations to end the <a href="/wiki/Vietnam_War" title="Vietnam War">Vietnam War</a>. As the Americans were strongly opposed to such policies, relations with Khánh became strained. (<b><a href="/wiki/September_1964_South_Vietnamese_coup_attempt" title="September 1964 South Vietnamese coup attempt">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><b>Armed conflicts and attacks</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Anbasah ibn Ishaq al-Dabbi
# <p><b>Anbasah ibn Isḥāq al-Ḍabbi</b> (<a class="mw-redirect" href="/wiki/Arabic_language" title="Arabic language">Arabic</a>: <span dir="rtl" lang="ar">عنبسة بن إسحاق الضبي</span>; died c. 860)<sup class="reference" id="cite_ref-FOOTNOTEAl-Mas'udi1873289_1-0"><a href="#cite_note-FOOTNOTEAl-Mas'udi1873289-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup> was a provincial governor for the <a href="/wiki/Abbasid_Caliphate" title="Abbasid Caliphate">Abbasid Caliphate</a> in the ninth century, serving as governor of <a href="/wiki/Raqqa" title="Raqqa">Raqqa</a> (833),<sup class="reference" id="cite_ref-FOOTNOTEAl-Tabari1985–2007v._32:_p._222_2-0"><a href="#cite_note-FOOTNOTEAl-Tabari1985–2007v._32:_p._222-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup> <a href="/wiki/Sindh" title="Sindh">al-Sind</a> (c. 840s) and <a href="/wiki/Egypt_in_the_Middle_Ages" title="Egypt in the Middle Ages">Egypt</a> (852–856). He was the last <a class="mw-redirect" href="/wiki/Arab" title="Arab">Arab</a> to hold the governorship of Egypt under the Abbasid caliphs, his successors thereafter being <a href="/wiki/Turkic_peoples" title="Turkic peoples">Turks</a>.
# </p>
# /w/index.php?title=Anbasah_ibn_Ishaq_al-Dabbi&action=edit
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1239334454">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyContributions
# User contributions for 49.149.140.144
# <p>No changes were found matching these criteria.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:49.149.140.144
# <p>People on Wikipedia can use this <a href="/wiki/Wikipedia:User_pages" title="Wikipedia:User pages">talk page</a> to post a public message about edits made from the IP address you are currently using.
# </p>
# /w/index.php?title=User_talk:49.149.140.144&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:49.149.140.144
# HTTP Error: 404 - Not Found
# --------------------
# /wiki/Special:Contributions/49.149.140.144
# User contributions for 49.149.140.144
# <p>No changes were found matching these criteria.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:User_contributions
# Help:User contributions
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help_talk:User_contributions
# Help talk:User contributions
# <p><big><br/>
# This page is for <a href="/wiki/Wikipedia:Talk_page_guidelines" title="Wikipedia:Talk page guidelines">discussion</a> of the <a href="/wiki/Help:User_contributions" title="Help:User contributions">User contributions</a> page itself. For other help, please go here:</big>
# </p>
# /w/index.php?title=Help_talk:User_contributions&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Help_talk:User_contributions
# Pages that link to "Help talk:User contributions"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Help_talk:User_contributions" title="Help talk:User contributions">Help talk:User contributions</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Help_talk:User_contributions&action=edit
# --------------------
# /wiki/Help:What_links_here
# Help:What links here
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help_talk:What_links_here
# Help talk:What links here
# <p><span data-mw-comment-start="" id="c-Philcha-2008-11-26T14:34:00.000Z-Advertising_removed"></span>I have removed from the end of this page {{h:f|enname=What links here}}, which produces the following advertising link. --<a href="/wiki/User:Philcha" title="User:Philcha">Philcha</a> (<a href="/wiki/User_talk:Philcha" title="User talk:Philcha">talk</a>) <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Help_talk:What_links_here#c-Philcha-2008-11-26T14:34:00.000Z-Advertising_removed">14:34, 26 November 2008 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-Philcha-2008-11-26T14:34:00.000Z-Advertising_removed"><span class="ext-discussiontools-init-replylink-bracket">[</span><a class="ext-discussiontools-init-replylink-reply" href="" role="button" tabindex="0">reply</a><span class="ext-discussiontools-init-replylink-bracket">]</span><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2008-11-26T14:34:00.000Z","author":"Philcha","type":"comment","level":1,"id":"c-Philcha-2008-11-26T14:34:00.000Z-Advertising_removed","replies":[]}}--></span><span data-mw-comment-end="c-Philcha-2008-11-26T14:34:00.000Z-Advertising_removed"></span>
# </p>
# /w/index.php?title=Help_talk:What_links_here&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Help_talk:What_links_here
# Pages that link to "Help talk:What links here"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Help_talk:What_links_here" title="Help talk:What links here">Help talk:What links here</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Help_talk:What_links_here&action=edit
# --------------------
# /wiki/Wikipedia:File_Upload_Wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia_talk:File_upload_wizard
# Wikipedia talk:File upload wizard
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:WhatLinksHere/Wikipedia_talk:File_upload_wizard
# Pages that link to "Wikipedia talk:File upload wizard"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Wikipedia_talk:File_upload_wizard" title="Wikipedia talk:File upload wizard">Wikipedia talk:File upload wizard</a></b> <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:SpecialPages
# Special pages
# <p>This page contains a list of <a href="/wiki/Help:Special_page" title="Help:Special page">special pages</a>. Most of the content of these pages is automatically generated and cannot be edited. To suggest a change to the parts that <i>can</i> be edited, find the appropriate text on <a href="/wiki/Special:AllMessages" title="Special:AllMessages">Special:AllMessages</a> and then request your change on the talk page of the message (using {{<a href="/wiki/Template:Edit_fully-protected" title="Template:Edit fully-protected">editprotected</a>}} to draw the attention of administrators).
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Special_page
# Help:Special page
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help_talk:Special_page
# Help talk:Special page
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Help_talk:Special_page&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Help_talk:Special_page
# Pages that link to "Help talk:Special page"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Help_talk:Special_page" title="Help talk:Special page">Help talk:Special page</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Help_talk:Special_page&action=edit
# --------------------
# /wiki/Help:What_links_here#Transclusion
# Help:What links here
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:WhatLinksHere/Help:What_links_here
# Pages that link to "Help:What links here"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Help:What_links_here" title="Help:What links here">Help:What links here</a></b> <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Talk:Vancouver_(disambiguation)
# Talk:Vancouver (disambiguation)
# <p><span data-mw-comment-start="" id="c-Tariqabjotu-2006-09-01T19:30:00.000Z-Old_discussions"></span>Is there any reason this page should not either be the actual location of the article on, or a redirect to, <a class="mw-redirect" href="/wiki/Vancouver,_British_Columbia" title="Vancouver, British Columbia">Vancouver, British Columbia</a> with a small disambiguation block at the top? Every link to this page is about the city in BC; it seems to be the natural direct link. --<a class="mw-redirect" href="/wiki/User:Brion_VIBBER" title="User:Brion VIBBER">Brion</a>
# </p>
# /w/index.php?title=Talk:Vancouver_(disambiguation)&action=edit
# --------------------
# /wiki/Vancouver_(disambiguation)
# Vancouver (disambiguation)
# <p><b><a href="/wiki/Vancouver" title="Vancouver">Vancouver</a></b> is the most populous city in British Columbia, Canada.
# </p>
# /w/index.php?title=Vancouver_(disambiguation)&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Vancouver_(disambiguation)
# Pages that link to "Vancouver (disambiguation)"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Vancouver_(disambiguation)" title="Vancouver (disambiguation)">Vancouver (disambiguation)</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Vancouver_(disambiguation)&action=edit
# --------------------
# /wiki/Vancouver
# Vancouver
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Talk:Vancouver
# Talk:Vancouver
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Talk:Vancouver&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:Vancouver
# Pages that link to "Talk:Vancouver"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:Vancouver" title="Talk:Vancouver">Talk:Vancouver</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:Vancouver&action=edit
# --------------------
# /wiki/Talk:Vancouver,_British_Columbia
# Talk:Vancouver, British Columbia
# /w/index.php?title=Talk:Vancouver,_British_Columbia&action=edit
# --------------------
# /wiki/Vancouver,_British_Columbia
# Vancouver
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special
ds of the White House."  Can anyone clarify this? Thanks.  <a href="/wiki/User:Billertl" title="User:Billertl">Billertl</a> (<a href="/wiki/User_talk:Billertl" title="User talk:Billertl">talk</a>) <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Talk:The_Birth_of_a_Nation/Archive_3#c-Billertl-2013-04-18T03:19:00.000Z-Disputed_Claim">03:19, 18 April 2013 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-Billertl-2013-04-18T03:19:00.000Z-Disputed_Claim"><!--__DTREPLYBUTTONSCONTENT__--><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2013-04-18T03:19:00.000Z","author":"Billertl","type":"comment","level":1,"id":"c-Billertl-2013-04-18T03:19:00.000Z-Disputed_Claim","replies":["c-Ewulp-2013-04-18T04:58:00.000Z-Billertl-2013-04-18T03:19:00.000Z"]}}--></span><span data-mw-comment-end="c-Billertl-2013-04-18T03:19:00.000Z-Disputed_Claim"></span>
# </p>
# /w/index.php?title=Talk:The_Birth_of_a_Nation/Archive_3&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:The_Birth_of_a_Nation/Archive_3
# Pages that link to "Talk:The Birth of a Nation/Archive 3"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:The_Birth_of_a_Nation/Archive_3" title="Talk:The Birth of a Nation/Archive 3">Talk:The Birth of a Nation/Archive 3</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:The_Birth_of_a_Nation/Archive_3&action=edit
# --------------------
# /wiki/User:ClueBot_III/Indices/Talk:The_Birth_of_a_Nation
# User:ClueBot III/Indices/Talk:The Birth of a Nation
# /w/index.php?title=User:ClueBot_III/Indices/Talk:The_Birth_of_a_Nation&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User:ClueBot_III/Indices/Talk:The_Birth_of_a_Nation
# HTTP Error: 404 - Not Found
# --------------------
# /wiki/Special:RecentChangesLinked/User:ClueBot_III/Indices/Talk:The_Birth_of_a_Nation
# HTTP Error: 404 - Not Found
# --------------------
# /wiki/Special:Contributions/ClueBot_III
# User contributions for ClueBot III
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Log/ClueBot_III
# Main public logs
# <p>This is a combined display of all logs except the patrol, review, tag and thanks logs:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Log
# Help:Log
# <p>A Wikipedia <b>log</b> is an automatically generated list of actions of a certain type, showing when they were performed, by what user, and with respect to what page or other user. Logged actions include page deletions and restorations, page moves (renames), user blocks and unblocks, page protections and unprotections, user account creations, abuse filter reports, and others.
# </p>
# /w/index.php?title=Help:Log&action=edit
# --------------------
# /wiki/Help_talk:Log
# Help talk:Log
# <p><span data-mw-comment-start="" id="c-Iiar-2015-02-18T04:52:00.000Z-Move_logs_of_the_target_titles"></span>I'm not sure if this is the best place to ask this but why aren't moves getting listed on the move logs (or even the "All public logs) of the target page title, at least when it comes to old moves? I'm specifically talking about <a class="external free" href="https://en.wikipedia.org/w/index.php?title=Special:Log&amp;page=Ninja+World&amp;hide_patrol_log=0&amp;hide_review_log=0&amp;hide_thanks_log=0">http://en.wikipedia.org/w/index.php?title=Special:Log&amp;page=Ninja+World&amp;hide_patrol_log=0&amp;hide_review_log=0&amp;hide_thanks_log=0</a>. I had to jump through several hoops before finding out that it had been moved two years ago, and that too only because I knew what it was called before then. Was there some change made to the software in the last two years that broke the old listings?--<a href="/wiki/User_talk:Iiar" title="User talk:Iiar"> <span style="color:aquamarine">pretty little </span> </a><a href="/wiki/User:Iiar" title="User:Iiar">Iiar</a> <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Help_talk:Log#c-Iiar-2015-02-18T04:52:00.000Z-Move_logs_of_the_target_titles">04:52, 18 February 2015 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-Iiar-2015-02-18T04:52:00.000Z-Move_logs_of_the_target_titles"><span class="ext-discussiontools-init-replylink-bracket">[</span><a class="ext-discussiontools-init-replylink-reply" href="" role="button" tabindex="0">reply</a><span class="ext-discussiontools-init-replylink-bracket">]</span><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2015-02-18T04:52:00.000Z","author":"Iiar","type":"comment","level":1,"id":"c-Iiar-2015-02-18T04:52:00.000Z-Move_logs_of_the_target_titles","replies":["c-PrimeHunter-2015-02-18T13:07:00.000Z-Iiar-2015-02-18T04:52:00.000Z"]}}--></span><span data-mw-comment-end="c-Iiar-2015-02-18T04:52:00.000Z-Move_logs_of_the_target_titles"></span>
# </p>
# /w/index.php?title=Help_talk:Log&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Help_talk:Log
# Pages that link to "Help talk:Log"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Help_talk:Log" title="Help talk:Log">Help talk:Log</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Help_talk:Log&action=edit
# --------------------
# /wiki/Wikipedia:Village_pump_(technical)/Archive_134
# Wikipedia:Village pump (technical)/Archive 134
# <p style="margin:0.5em;">This page contains discussions that have been archived from <a href="/wiki/Wikipedia:Village_pump_(technical)" title="Wikipedia:Village pump (technical)">Village pump (technical)</a>. Please do not edit the contents of this page. If you wish to revive any of these discussions, either <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Wikipedia:Village_pump_(technical)&amp;action=edit&amp;section=new">start</a> a new thread or use the talk page associated with that topic.</p>
# /w/index.php?title=Wikipedia:Village_pump_(technical)/Archive_134&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Wikipedia:Village_pump_(technical)/Archive_134
# Pages that link to "Wikipedia:Village pump (technical)/Archive 134"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Wikipedia:Village_pump_(technical)/Archive_134" title="Wikipedia:Village pump (technical)/Archive 134">Wikipedia:Village pump (technical)/Archive 134</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Wikipedia:Village_pump_(technical)/Archive_134&action=edit
# --------------------
# /wiki/Talk:Particle_physics_and_representation_theory
# Talk:Particle physics and representation theory
# <p>There are a number of items that I put on this page that I'm not 100% sure about. For example, I'm not sure exactly what Wigner's Theorem is or how it fits in. I also may be misstating the facts about color and flavour symmetry, and I may be oversymplifying the classification of representations of the Poincare group. <a href="/wiki/User:Sbyrnes321" title="User:Sbyrnes321">Steve</a>
# </p>
# /w/index.php?title=Talk:Particle_physics_and_representation_theory&action=edit
# --------------------
# /wiki/Particle_physics_and_representation_theory
# Particle physics and representation theory
# <p>There is a natural connection between <a href="/wiki/Particle_physics" title="Particle physics">particle physics</a> and <a href="/wiki/Representation_theory" title="Representation theory">representation theory</a>, as first noted in the 1930s by <a href="/wiki/Eugene_Wigner" title="Eugene Wigner">Eugene Wigner</a>.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup> It links the properties of <a href="/wiki/Elementary_particle" title="Elementary particle">elementary particles</a> to the structure of <a href="/wiki/Lie_group" title="Lie group">Lie groups</a> and <a href="/wiki/Lie_algebra" title="Lie algebra">Lie algebras</a>. According to this connection, the different <a href="/wiki/Quantum_state" title="Quantum state">quantum states</a> of an elementary particle give rise to an <a href="/wiki/Irreducible_representation" title="Irreducible representation">irreducible representation</a> of the <a href="/wiki/Poincar%C3%A9_group" title="Poincaré group">Poincaré group</a>. Moreover, the properties of the various particles, including their <a class="mw-redirect" href="/wiki/Energy_spectrum" title="Energy spectrum">spectra</a>, can be related to representations of Lie algebras, corresponding to "approximate symmetries" of the universe.
# </p>
# /w/index.php?title=Particle_physics_and_representation_theory&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Particle_physics_and_representation_theory
# Pages that link to "Particle physics and representation theory"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Particle_physics_and_representation_theory" title="Particle physics and representation theory">Particle physics and representation theory</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Particle_physics_and_representation_theory&action=edit
# --------------------
# /wiki/Algorithm
# Algorithm
# <p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a> and <a href="/wiki/Computer_science" title="Computer science">computer science</a>, an <b>algorithm</b> (<span class="rt-commentedText nowrap"><span class="IPA nopopups noexcerpt" lang="en-fonipa"><a href="/wiki/Help:IPA/English" title="Help:IPA/English">/<span style="border-bottom:1px dotted"><span title="/ˈ/: primary stress follows">ˈ</span><span title="/æ/: 'a' in 'bad'">æ</span><span title="'l' in 'lie'">l</span><span title="/ɡ/: 'g' in 'guy'">ɡ</span><span title="/ə/: 'a' in 'about'">ə</span><span title="'r' in 'rye'">r</span><span title="/ɪ/: 'i' in 'kit'">ɪ</span><span title="/ð/: 'th' in 'this'">ð</span><span title="/əm/: 'm' in 'rhythm'">əm</span></span>/</a></span> <span class="noprint"><span class="ext-phonos"><span class="ext-phonos-PhonosButton noexcerpt ext-phonos-PhonosButton-emptylabel oo-ui-widget oo-ui-widget-enabled oo-ui-buttonElement oo-ui-buttonElement-frameless oo-ui-iconElement oo-ui-buttonWidget" data-nosnippet="" data-ooui='{"_":"mw.Phonos.PhonosButton","href":"\/\/upload.wikimedia.org\/wikipedia\/commons\/transcoded\/7\/7f\/En-us-algorithm.ogg\/En-us-algorithm.ogg.mp3","rel":["nofollow"],"framed":false,"icon":"volumeUp","data":{"ipa":"","text":"","lang":"en","wikibase":"","file":"En-us-algorithm.ogg"},"classes":["ext-phonos-PhonosButton","noexcerpt","ext-phonos-PhonosButton-emptylabel"]}' id="ooui-php-1"><a aria-label="Play audio" class="oo-ui-buttonElement-button" href="//upload.wikimedia.org/wikipedia/commons/transcoded/7/7f/En-us-algorithm.ogg/En-us-algorithm.ogg.mp3" rel="nofollow" role="button" tabindex="0" title="Play audio"><span class="oo-ui-iconElement-icon oo-ui-icon-volumeUp"></span><span class="oo-ui-labelElement-label"></span><span class="oo-ui-indicatorElement-indicator oo-ui-indicatorElement-noIndicator"></span></a></span><sup class="ext-phonos-attribution noexcerpt navigation-not-searchable"><a href="/wiki/File:En-us-algorithm.ogg" title="File:En-us-algorithm.ogg">ⓘ</a></sup></span></span></span>) is a <a class="extiw" href="https://www.merriam-webster.com/dictionary/finite" title="mwod:finite">finite</a> sequence of <a href="/wiki/Rigour#Mathematics" title="Rigour">mathematically rigorous</a> instructions, typically used to solve a class of specific <a href="/wiki/Computational_problem" title="Computational problem">problems</a> or to perform a <a href="/wiki/Computation" title="Computation">computation</a>.<sup class="reference" id="cite_ref-:0_1-0"><a href="#cite_note-:0-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup> Algorithms are used as specifications for performing <a href="/wiki/Calculation" title="Calculation">calculations</a> and <a href="/wiki/Data_processing" title="Data processing">data processing</a>. More advanced algorithms can use <a href="/wiki/Conditional_(computer_programming)" title="Conditional (computer programming)">conditionals</a> to divert the code execution through various routes (referred to as <a href="/wiki/Automated_decision-making" title="Automated decision-making">automated decision-making</a>) and deduce valid <a href="/wiki/Inference" title="Inference">inferences</a> (referred to as <a href="/wiki/Automated_reasoning" title="Automated reasoning">automated reasoning</a>), achieving <a href="/wiki/Automation" title="Automation">automation</a> eventually. Using human characteristics as descriptors of machines in metaphorical ways was already practiced by <a href="/wiki/Alan_Turing" title="Alan Turing">Alan Turing</a> with terms such as "memory", "search" and "stimulus".<sup class="reference" id="cite_ref-:1_2-0"><a href="#cite_note-:1-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup>
# </p>
# /w/index.php?title=Algorithm&action=edit
# --------------------
# /wiki/Talk:Algorithm
# Talk:Algorithm
# <p>
# <link href="mw-data:TemplateStyles:r1237879475" rel="mw-deduplicated-inline-style"/>
# </p>
# /w/index.php?title=Talk:Algorithm&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:Algorithm
# Pages that link to "Talk:Algorithm"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:Algorithm" title="Talk:Algorithm">Talk:Algorithm</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:Algorithm&action=edit
# --------------------
# /wiki/Talk:Computability_theory_(computer_science)
# Talk:Computability theory (computer science)
# <p>I believe the Entscheidungsproblem was first proved unsolvable by Church, and months later by Turing. Goedel's theorems don't really talk about algorithms, so they don't directly apply. Of course, Goedel's trick of Goedel numbering and the Barber paradox is really the key to the Entscheidungsproblem and halting problem, everything else is details. --AxelBoldt
# </p>
# /w/index.php?title=Talk:Computability_theory_(computer_science)&action=edit
# --------------------
# /wiki/Computability_theory_(computer_science)
# Computability theory
# <p>
# <b>Computability theory</b>, also known as <b>recursion theory</b>, is a branch of <a href="/wiki/Mathematical_logic" title="Mathematical logic">mathematical logic</a>, <a href="/wiki/Computer_science" title="Computer science">computer science</a>, and the <a href="/wiki/Theory_of_computation" title="Theory of computation">theory of computation</a> that originated in the 1930s with the study of <a href="/wiki/Computable_function" title="Computable function">computable functions</a> and <a href="/wiki/Turing_degree" title="Turing degree">Turing degrees</a>. The field has since expanded to include the study of generalized <a href="/wiki/Computability" title="Computability">computability</a> and <a href="/wiki/Definable_set" title="Definable set">definability</a>. In these areas, computability theory overlaps with <a href="/wiki/Proof_theory" title="Proof theory">proof theory</a> and <a href="/wiki/Effective_descriptive_set_theory" title="Effective descriptive set theory">effective descriptive set theory</a>.
# </p>
# /w/index.php?title=Computability_theory&action=edit
# --------------------
# /wiki/Computability_theory
# Computability theory
# <p>
# <b>Computability theory</b>, also known as <b>recursion theory</b>, is a branch of <a href="/wiki/Mathematical_logic" title="Mathematical logic">mathematical logic</a>, <a href="/wiki/Computer_science" title="Computer science">computer science</a>, and the <a href="/wiki/Theory_of_computation" title="Theory of computation">theory of computation</a> that originated in the 1930s with the study of <a href="/wiki/Computable_function" title="Computable function">computable functions</a> and <a href="/wiki/Turing_degree" title="Turing degree">Turing degrees</a>. The field has since expanded to include the study of generalized <a href="/wiki/Computability" title="Computability">computability</a> and <a href="/wiki/Definable_set" title="Definable set">definability</a>. In these areas, computability theory overlaps with <a href="/wiki/Proof_theory" title="Proof theory">proof theory</a> and <a href="/wiki/Effective_descriptive_set_theory" title="Effective descriptive set theory">effective descriptive set theory</a>.
# </p>
# /w/index.php?title=Computability_theory&action=edit
# --------------------
# /wiki/Talk:Computability_theory
# Talk:Computability theory
# <p><span data-mw-comment-start="" id="c-Deville-2006-02-08T12:33:00.000Z-Should_this_page_even_exist?"></span>I was checking out this disambiguation page with a view towards disambiguating the links, and I wonder: should this page exist?  I am sure that there are some set theorists who have used the term "computability theory" to describe <a class="mw-redirect" href="/wiki/Recursion_theory" title="Recursion theory">recursion theory</a>, but I'm willing to bet that if I were to go through <a class="external text" href="https://en.wikipedia.org/wiki/Special:Whatlinkshere/Computability_theory">the links to this page</a> all, or almost all, should point to <a class="mw-redirect" href="/wiki/Computability_theory_(computer_science)" title="Computability theory (computer science)">computability theory (computer science)</a>.  Now, of course I could be wrong which is why I am asking here.  Any comments?   --<a href="/wiki/User:Deville" title="User:Deville">Deville</a> (<a href="/wiki/User_talk:Deville" title="User talk:Deville">Talk</a>) <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Talk:Computability_theory#c-Deville-2006-02-08T12:33:00.000Z-Should_this_page_even_exist?">12:33, 8 February 2006 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-Deville-2006-02-08T12:33:00.000Z-Should_this_page_even_exist?"><span class="ext-discussiontools-init-replylink-bracket">[</span><a class="ext-discussiontools-init-replylink-reply" href="" role="button" tabindex="0">reply</a><span class="ext-discussiontools-init-replylink-bracket">]</span><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2006-02-08T12:33:00.000Z","author":"Deville","type":"comment","level":1,"id":"c-Deville-2006-02-08T12:33:00.000Z-Should_this_page_even_exist?","replies":["c-R.Koot-2006-02-08T12:45:00.000Z-Deville-2006-02-08T12:33:00.000Z"]}}--></span><span data-mw-comment-end="c-Deville-2006-02-08T12:33:00.000Z-Should_this_page_even_exist?"></span>
# </p>
# /w/index.php?title=Talk:Computability_theory&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:Computability_theory
# Pages that link to "Talk:Computability theory"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:Computability_theory" title="Talk:Computability theory">Talk:Computability theory</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:Computability_theory&action=edit
# --------------------
# /wiki/Talk:Partial_function
# Talk:Partial function
# <p><i><span data-mw-comment-start="" id="c-Trovatore-2005-09-06T19:12:00.000Z-2005"></span>If a partial function associates with every element in its codomain precisely one element of its domain, then it is called a total function, or simply a function.</i>
# </p>
# /w/index.php?title=Talk:Partial_function&action=edit
# --------------------
# /wiki/Partial_function
# Partial function
# <p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>partial function</b> <span class="texhtml mvar" style="font-style:italic;">f</span> from a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> <span class="texhtml mvar" style="font-style:italic;">X</span> to a set <span class="texhtml mvar" style="font-style:italic;">Y</span> is a <a href="/wiki/Function_(mathematics)" title="Function (mathematics)">function</a> from a <a href="/wiki/Subset" title="Subset">subset</a> <span class="texhtml mvar" style="font-style:italic;">S</span> of <span class="texhtml mvar" style="font-style:italic;">X</span> (possibly the whole <span class="texhtml mvar" style="font-style:italic;">X</span> itself) to <span class="texhtml mvar" style="font-style:italic;">Y</span>. The subset <span class="texhtml mvar" style="font-style:italic;">S</span>, that is, the <i><a href="/wiki/Domain_of_a_function" title="Domain of a function">domain</a></i> of <span class="texhtml mvar" style="font-style:italic;">f</span> viewed as a function, is called the <b>domain of definition</b> or <b>natural domain</b> of <span class="texhtml mvar" style="font-style:italic;">f</span>. If <span class="texhtml mvar" style="font-style:italic;">S</span> equals <span class="texhtml mvar" style="font-style:italic;">X</span>, that is, if <span class="texhtml mvar" style="font-style:italic;">f</span> is defined on every element in <span class="texhtml mvar" style="font-style:italic;">X</span>, then <span class="texhtml mvar" style="font-style:italic;">f</span> is said to be a <b>total function</b>.
# </p>
# /w/index.php?title=Partial_function&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Partial_function
# Pages that link to "Partial function"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Partial_function" title="Partial function">Partial function</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Partial_function&action=edit
# --------------------
# /wiki/Binary_relation
# Binary relation
# <p>All definitions tacitly require the <a href="/wiki/Homogeneous_relation" title="Homogeneous relation">homogeneous relation</a> <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle R}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>R</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle R}</annotation>
# </semantics>
# ...
# </p>
# /w/index.php?title=Talk:Binary_relation&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:Binary_relation
# Pages that link to "Talk:Binary relation"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:Binary_relation" title="Talk:Binary relation">Talk:Binary relation</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:Binary_relation&action=edit
# --------------------
# /wiki/Talk:Relation_(mathematics)
# Talk:Relation (mathematics)
# <p><i><span data-mw-comment-start="" id="c-Wikid77-2009-05-02T03:48:00.000Z-Convert_to_overview_of_relations"></span>02-May-09:</i> The page should be converted into a short overview of the topic, as already named appropriately, to describe "<a href="/wiki/Relation_(mathematics)" title="Relation (mathematics)">Relation (mathematics)</a>". -<a href="/wiki/User:Wikid77" title="User:Wikid77">Wikid77</a> (<a href="/wiki/User_talk:Wikid77" title="User talk:Wikid77">talk</a>) <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Talk:Relation_(mathematics)#c-Wikid77-2009-05-02T03:48:00.000Z-Convert_to_overview_of_relations">03:48, 2 May 2009 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-Wikid77-2009-05-02T03:48:00.000Z-Convert_to_overview_of_relations"><span class="ext-discussiontools-init-replylink-bracket">[</span><a class="ext-discussiontools-init-replylink-reply" href="" role="button" tabindex="0">reply</a><span class="ext-discussiontools-init-replylink-bracket">]</span><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2009-05-02T03:48:00.000Z","author":"Wikid77","type":"comment","level":1,"id":"c-Wikid77-2009-05-02T03:48:00.000Z-Convert_to_overview_of_relations","replies":[]}}--></span><span data-mw-comment-end="c-Wikid77-2009-05-02T03:48:00.000Z-Convert_to_overview_of_relations"></span>
# </p>
# /w/index.php?title=Talk:Relation_(mathematics)&action=edit
# --------------------
# /wiki/Relation_(mathematics)
# Relation (mathematics)
# <p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>relation</b> denotes some kind of <i>relationship</i> between two <a href="/wiki/Mathematical_object" title="Mathematical object">objects</a> in a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a>, which may or may not hold.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup> As an example, "<i>is less than</i>" is a relation on the set of <a href="/wiki/Natural_number" title="Natural number">natural numbers</a>; it holds, for instance, between the values <span class="texhtml">1</span> and <span class="texhtml">3</span> (denoted as <span class="texhtml">1 &lt; 3</span>), and likewise between <span class="texhtml">3</span> and <span class="texhtml">4</span> (denoted as <span class="texhtml">3 &lt; 4</span>), but not between the values <span class="texhtml">3</span> and <span class="texhtml">1</span> nor between <span class="texhtml">4</span> and <span class="texhtml">4</span>, that is, <span class="texhtml">3 &lt; 1</span> and <span class="texhtml">4 &lt; 4</span> both evaluate to false.
# As another example, "<i>is sister of</i><span style="padding-left:.15em;">"</span> is a relation on the set of all people, it holds e.g. between <a href="/wiki/Marie_Curie" title="Marie Curie">Marie Curie</a> and <a href="/wiki/Bronis%C5%82awa_D%C5%82uska" title="Bronisława Dłuska">Bronisława Dłuska</a>, and likewise vice versa.
# Set members may not be in relation "to a certain degree" – either they are in relation or they are not.
# </p>
# /w/index.php?title=Relation_(mathematics)&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Relation_(mathematics)
# Pages that link to "Relation (mathematics)"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Relation_(mathematics)" title="Relation (mathematics)">Relation (mathematics)</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Relation_(mathematics)&action=edit
# --------------------
# /wiki/Axiom_of_choice
# Axiom of choice
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Axiom_of_choice&action=edit
# --------------------
# /wiki/Talk:Axiom_of_choice
# Talk:Axiom of choice
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Talk:Axiom_of_choice&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:Axiom_of_choice
# Pages that link to "Talk:Axiom of choice"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:Axiom_of_choice" title="Talk:Axiom of choice">Talk:Axiom of choice</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:Axiom_of_choice&action=edit
# --------------------
# /wiki/List_of_mathematical_logic_topics
# List of mathematical logic topics
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=List_of_mathematical_logic_topics&action=edit
# --------------------
# /wiki/Talk:List_of_mathematical_logic_topics
# Talk:List of mathematical logic topics
# <p><span data-mw-comment-start="" id="c-DJSlater00-2009-04-21T10:02:00.000Z-a_suggestion_about_topics"></span>I noticed formal grammars and category theory aren't mentioned.I think it might be a useful addition.
# --<a class="new" href="/w/index.php?title=User:DJSlater00&amp;action=edit&amp;redlink=1" title="User:DJSlater00 (page does not exist)">DJSlater00</a> (<a href="/wiki/User_talk:DJSlater00" title="User talk:DJSlater00">talk</a>) <a class="ext-discussiontools-init-timestamplink" href="https://en.wikipedia.org/wiki/Talk:List_of_mathematical_logic_topics#c-DJSlater00-2009-04-21T10:02:00.000Z-a_suggestion_about_topics">10:02, 21 April 2009 (UTC)</a><span class="ext-discussiontools-init-replylink-buttons" data-mw-thread-id="c-DJSlater00-2009-04-21T10:02:00.000Z-a_suggestion_about_topics"><span class="ext-discussiontools-init-replylink-bracket">[</span><a class="ext-discussiontools-init-replylink-reply" href="" role="button" tabindex="0">reply</a><span class="ext-discussiontools-init-replylink-bracket">]</span><!--__DTELLIPSISBUTTON__{"threadItem":{"timestamp":"2009-04-21T10:02:00.000Z","author":"DJSlater00","type":"comment","level":1,"id":"c-DJSlater00-2009-04-21T10:02:00.000Z-a_suggestion_about_topics","replies":[]}}--></span><span data-mw-comment-end="c-DJSlater00-2009-04-21T10:02:00.000Z-a_suggestion_about_topics"></span>
# </p>
# /w/index.php?title=Talk:List_of_mathematical_logic_topics&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Talk:List_of_mathematical_logic_topics
# Pages that link to "Talk:List of mathematical logic topics"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Talk:List_of_mathematical_logic_topics" title="Talk:List of mathematical logic topics">Talk:List of mathematical logic topics</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Talk:List_of_mathematical_logic_topics&action=edit
# --------------------
# /wiki/Wikipedia:WikiProject_Outlines/Watchlist_using_Related_changes
# Wikipedia:WikiProject Outlines/Watchlist using Related changes
# <p>Below is the project's watchlist. To use, click "<b>Related changes</b>" in the toolbox menu on the sidebar on the left side of the screen. (Watch out, it's easy to click on "Recent changes" by mistake).
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Outlines/Watchlist_using_Related_changes&action=edit
# --------------------
# /wiki/Wikipedia_talk:WikiProject_Outlines/Watchlist_using_Related_changes
# Wikipedia talk:WikiProject Outlines/Watchlist using Related changes
# <p>This page is for discussing the WPOOK's RC watchlist.
# </p>
# /w/index.php?title=Wikipedia_talk:WikiProject_Outlines/Watchlist_using_Related_changes&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/Wikipedia_talk:WikiProject_Outlines/Watchlist_using_Related_changes
# Pages that link to "Wikipedia talk:WikiProject Outlines/Watchlist using Related changes"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Wikipedia_talk:WikiProject_Outlines/Watchlist_using_Related_changes" title="Wikipedia talk:WikiProject Outlines/Watchlist using Related changes">Wikipedia talk:WikiProject Outlines/Watchlist using Related changes</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=Wikipedia_talk:WikiProject_Outlines/Watchlist_using_Related_changes&action=edit
# --------------------
# /wiki/User_talk:Minnecologies/Archive_1
# User talk:Minnecologies/Archive 1
# <p><b>Welcome!</b>
# </p>
# /w/index.php?title=User_talk:Minnecologies/Archive_1&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:Minnecologies/Archive_1
# Pages that link to "User talk:Minnecologies/Archive 1"
# <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/User_talk:Minnecologies/Archive_1" title="User talk:Minnecologies/Archive 1">User talk:Minnecologies/Archive 1</a></b> <span id="specialDeleteLink"></span>
# </p>
# /w/index.php?title=User_talk:Minnecologies/Archive_1&action=edit
# --------------------
# /wiki/Special:Contributions/Minnecologies
# User contributions for Minnecologies
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Log/Minnecologies
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 33
#      31                 pages.add(newPage)
#      32                 getLinks(newPage)
# ---> 33 getLinks('/wiki/General-purpose_programming_language')
#
# Cell In[8], line 32, in getLinks(pageUrl)
#      30 print(newPage)
#      31 pages.add(newPage)
# ---> 32 getLinks(newPage)
#
# Cell In[8], line 32, in getLinks(pageUrl)
#      30 print(newPage)
#      31 pages.add(newPage)
# ---> 32 getLinks(newPage)
#
#     [... skipping similar frames: getLinks at line 32 (91 times)]
#
# Cell In[8], line 32, in getLinks(pageUrl)
#      30 print(newPage)
#      31 pages.add(newPage)
# ---> 32 getLinks(newPage)
#
# Cell In[8], line 9, in getLinks(pageUrl)
#       7 def getLinks(pageUrl):
#       8     try:
# ----> 9         html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#      10     except HTTPError as e:
#      11         print(f'HTTP Error: {e.code} - {e.reason}')
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.10/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.10/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File /usr/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.10/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File /usr/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# Random external link is: https://www.oreilly.com/member/login/
# Random external link is: https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 51
#      47     print(f'Random external link is: {externalLink}')
#      48     followExternalOnly(externalLink)
# ---> 51 followExternalOnly('https://www.oreilly.com/')
#
# Cell In[9], line 48, in followExternalOnly(startingSite)
#      46 externalLink = getRandomExternalLink(startingSite)
#      47 print(f'Random external link is: {externalLink}')
# ---> 48 followExternalOnly(externalLink)
#
# Cell In[9], line 48, in followExternalOnly(startingSite)
#      46 externalLink = getRandomExternalLink(startingSite)
#      47 print(f'Random external link is: {externalLink}')
# ---> 48 followExternalOnly(externalLink)
#
# Cell In[9], line 48, in followExternalOnly(startingSite)
#      46 externalLink = getRandomExternalLink(startingSite)
#      47 print(f'Random external link is: {externalLink}')
# ---> 48 followExternalOnly(externalLink)
#
# Cell In[9], line 46, in followExternalOnly(startingSite)
#      45 def followExternalOnly(startingSite):
# ---> 46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
#      48     followExternalOnly(externalLink)
#
# Cell In[9], line 41, in getRandomExternalLink(startingPage)
#      39     print('No external links, looking around the site for one')
#      40     internalLinks = getInternalLinks(bs, startingPage)
# ---> 41     return getRandomExternalLink(random.choice(internalLinks))
#      42 else:
#      43     return random.choice(externalLinks)
#
# Cell In[9], line 41, in getRandomExternalLink(startingPage)
#      39     print('No external links, looking around the site for one')
#      40     internalLinks = getInternalLinks(bs, startingPage)
# ---> 41     return getRandomExternalLink(random.choice(internalLinks))
#      42 else:
#      43     return random.choice(externalLinks)
#
#     [... skipping similar frames: getRandomExternalLink at line 41 (90 times)]
#
# Cell In[9], line 41, in getRandomExternalLink(startingPage)
#      39     print('No external links, looking around the site for one')
#      40     internalLinks = getInternalLinks(bs, startingPage)
# ---> 41     return getRandomExternalLink(random.choice(internalLinks))
#      42 else:
#      43     return random.choice(externalLinks)
#
# Cell In[9], line 36, in getRandomExternalLink(startingPage)
#      35 def getRandomExternalLink(startingPage):
# ---> 36     bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
#      37     externalLinks = getExternalLinks(bs, startingPage)
#      38     if not len(externalLinks):
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# File /usr/lib/python3.10/http/client.py:481, in HTTPResponse.read(self, amt)
#     479 else:
#     480     try:
# --> 481         s = self._safe_read(self.length)
#     482     except IncompleteRead:
#     483         self._close_conn()
#
# File /usr/lib/python3.10/http/client.py:630, in HTTPResponse._safe_read(self, amt)
#     623 def _safe_read(self, amt):
#     624     """Read the number of bytes requested.
#     625
#     626     This function should be used when <amt> bytes "should" be present for
#     627     reading. If the bytes are truly not available (due to EOF), then the
#     628     IncompleteRead exception can be used to detect the problem.
#     629     """
# --> 630     data = self.fp.read(amt)
#     631     if len(data) < amt:
#     632         raise IncompleteRead(data, amt-len(data))
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collect all External Links from a Site

# %%
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
from urllib.parse import urlparse, quote
from bs4 import BeautifulSoup
import re


def isValidURL(url):
    parsed = urlparse(url)
    if parsed.scheme in ['http', 'https'] and ' ' not in url:
        if not parsed.scheme.startswith(('mailto', 'tel', 'javascript')):
            return True
    return False


def cleanURL(url):
    # Replace spaces with %20 to avoid InvalidURL errors
    return quote(url, safe=':/')

def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    
    for link in bs.find_all('a'):
        href = link.attrs.get('href')
        if not href:
            continue
        
        if href.startswith(('tel:', 'mailto:', 'javascript:')):
            continue
            
        # Check and clean the URL
        href = cleanURL(href)
        parsed = urlparse(href)
        
        # Make sure the link is an external link (not the same domain) and valid
        if parsed.netloc != '' and parsed.netloc != netloc:
            if isValidURL(href):
                externalLinks.add(href)
    
    return list(externalLinks)


def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        href = link.attrs.get('href')
        if not href:
            continue

        parsed = urlparse(href)

        # Check for internal links (same domain) and ignore schemes like 'tel:', 'mailto:'
        if parsed.netloc == '' and not href.startswith(('tel:', 'mailto:', 'javascript:')):
            internalLinks.add(f'{scheme}://{netloc}/{href.strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(href)
    return list(internalLinks)

# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    try:
        bs = BeautifulSoup(urlopen(url), 'html.parser')
    except HTTPError as e:
        print(f'HTTP Error: {e.code} - {e.reason}')
        return
    
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/search/%3Fquery%3Dauthor%253A%2522Kelsey%2520Hightower%2522%26extended_publisher_data%3Dtrue%26highlight%3Dtrue%26include_assessments%3Dfalse%26include_case_studies%3Dtrue%26include_courses%3Dtrue%26include_playlists%3Dtrue%26include_collections%3Dtrue%26include_notebooks%3Dtrue%26include_sandboxes%3Dtrue%26include_scenarios%3Dtrue%26is_academic_institution_account%3Dfalse%26source%3Duser%26sort%3Ddate_added%26facet_json%3Dtrue%26json_facets%3Dtrue%26page%3D0%26include_facets%3Dfalse
# https://www.linkedin.com/company/oreilly-media
# https://learning.oreilly.com/search/%3Fquery%3Dauthor%253A%2522Ken%2520Kousen%2522%26extended_publisher_data%3Dtrue%26highlight%3Dtrue%26include_assessments%3Dfalse%26include_case_studies%3Dtrue%26include_courses%3Dtrue%26include_playlists%3Dtrue%26include_collections%3Dtrue%26include_notebooks%3Dtrue%26include_sandboxes%3Dtrue%26include_scenarios%3Dtrue%26is_academic_institution_account%3Dfalse%26source%3Duser%26sort%3Ddate_added%26facet_json%3Dtrue%26json_facets%3Dtrue%26page%3D0%26include_facets%3Dfalse
# https://www.youtube.com/user/OreillyMedia
# http://www.carlotaperez.org/
# http://animals.oreilly.com/
# http://www.xyz.reply.it/web20/
# http://japan.cnet.com/column/web20/story/0%2C2000054679%2C20090039-5%2C00.htm
# http://shop.oreilly.com/category/customer-service/oreilly-guarantee.do
# http://shop.oreilly.com/category/customer-service/ordering-payment.do
# http://conferences.oreilly.com/
# http://elists.oreilly.com
# http://oreilly.com/feeds/
# http://makezine.com/
# http://www.mazen.com.sa/what-is-web2/page1.htm
# https://plus.google.com/%2Boreillymedia/
# http://craftzine.com/
# http://www.facebook.com/OReilly
# http://sociedaddelainformacion.telefonica.es/jsp/articulos/detalle.jsp%3Felem%3D2146
# http://forums.oreilly.com/
# http://blogs.forbes.com/oreillymedia/
# http://feeds.feedburner.com/oreilly/news
# http://www.enet.com.cn/article/2005/1122/A20051122474593.shtml
# https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2022/statistics-show-women-in-technology-are-facing-new-headwinds.html
# https://cdn.oreillystatic.com/pdf/OReilly_Capabilities_Statement.pdf
# https://www.gsaelibrary.gsa.gov/ElibMain/contractorInfo.do%3FcontractNumber%3D47QTCA19D0022%26contractorName%3DO%2527REILLY%2BMEDIA%252C%2BINC%26executeQuery%3DYES
# https://ae.oreilly.com/Modern_Defense_in_Depth
# https://learning.oreilly.com/playlists/483448db-86c6-464c-ade0-7545df1d3abd/
# https://oreil.ly/TlldE
# https://oreil.ly/1lqzK
# https://oreil.ly/Xakgc
# https://oreil.ly/NW3WX
# https://get.oreilly.com/ind_software-architecture-patterns.html
# https://oreil.ly/V40zg
# https://oreil.ly/3bWjz
# https://oreil.ly/KW5PS
# https://oreil.ly/VCcgy
# https://oreil.ly/UTxpX
# https://oreil.ly/Fc8cq
# https://discord.com
# https://oreil.ly/oGv4j
# https://oreil.ly/NQcFW
# https://oreil.ly/yU27T
# https://oreil.ly/2KDV6
# https://oreil.ly/iZhMl
# https://oreil.ly/TEiQx
# https://www.ebooks.com/search/%3Fterm%3D9781098153434%26affid%3DOMI5374258
# https://www.midjourney.com
# https://oreil.ly/P2IcU
# https://learning.oreilly.com/signup/
# https://oreil.ly/KGAqe
# https://oreil.ly/KG5Xl
# https://oreil.ly/IaQjS
# https://oreil.ly/dF8q-
# https://oreil.ly/huVRu
# https://oreil.ly/J4Hkr
# https://oreil.ly/q7wQF
# https://openai.com/pricing
# https://oreil.ly/DZ-br
# https://oreil.ly/RYYiV
# https://oreil.ly/oHID1
# https://oreil.ly/iEGZ9
# https://oreil.ly/wolEL
# https://oreil.ly/3TTZ9
# https://oreil.ly/48lq6
# https://oreil.ly/E7wua
# https://www.langchain.com
# https://oreil.ly/tPPW9
# https://oreil.ly/cyhR4
# https://chat.openai.com
# https://oreil.ly/Dwszu
# https://s.mj.run/TKAsyhNiKmc
# https://oreil.ly/0MZ3-
# https://learning.oreilly.com/library/view/prompt-engineering-for/9781098153427/
# https://oreil.ly/42rSz
# https://oreil.ly/txhSZ
# https://oreil.ly/ZbzZy
# https://oreil.ly/6Ixcw
# https://www.amazon.com/_/dp/109815343X%3Fsmid%3DATVPDKIKX0DER%26_encoding%3DUTF8%26tag%3Doreilly20-20
# HTTP Error: 404 - Not Found
# HTTP Error: 404 - Not Found
# https://learning.oreilly.com/register/
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/
html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 88
#      84             getAllExternalLinks(link)
#      87 allIntLinks.append('https://oreilly.com')
# ---> 88 getAllExternalLinks('https://www.oreilly.com/')
#
# Cell In[15], line 84, in getAllExternalLinks(url)
#      82 if link not in allIntLinks:
#      83     allIntLinks.append(link)
# ---> 84     getAllExternalLinks(link)
#
# Cell In[15], line 84, in getAllExternalLinks(url)
#      82 if link not in allIntLinks:
#      83     allIntLinks.append(link)
# ---> 84     getAllExternalLinks(link)
#
#     [... skipping similar frames: getAllExternalLinks at line 84 (62 times)]
#
# Cell In[15], line 84, in getAllExternalLinks(url)
#      82 if link not in allIntLinks:
#      83     allIntLinks.append(link)
# ---> 84     getAllExternalLinks(link)
#
# Cell In[15], line 69, in getAllExternalLinks(url)
#      67 def getAllExternalLinks(url):
#      68     try:
# ---> 69         bs = BeautifulSoup(urlopen(url), 'html.parser')
#      70     except HTTPError as e:
#      71         print(f'HTTP Error: {e.code} - {e.reason}')
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File /usr/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1279 def request(self, method, url, body=None, headers={}, *,
#    1280             encode_chunked=False):
#    1281     """Send a complete request to the server."""
# -> 1282     self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1324 if isinstance(body, str):
#    1325     # RFC 2616 Section 3.7.1 says that text default has a
#    1326     # default charset of iso-8859-1.
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1275 else:
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1035 msg = b"\r\n".join(self._buffer)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#    1042     if hasattr(message_body, 'read'):
#    1043         # Let file-like take precedence over byte-like.  This
#    1044         # is needed to allow the current position of mmap'ed
#    1045         # files to be taken into account.
#
# File /usr/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     973 if self.sock is None:
#     974     if self.auto_open:
# --> 975         self.connect()
#     976     else:
#     977         raise NotConnected()
#
# File /usr/lib/python3.10/http/client.py:1447, in HTTPSConnection.connect(self)
#    1444 def connect(self):
#    1445     "Connect to a host on a given (SSL) port."
# -> 1447     super().connect()
#    1449     if self._tunnel_host:
#    1450         server_hostname = self._tunnel_host
#
# File /usr/lib/python3.10/http/client.py:941, in HTTPConnection.connect(self)
#     939 """Connect to the host and port specified in __init__."""
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#     944 try:
#
# File /usr/lib/python3.10/socket.py:824, in create_connection(address, timeout, source_address)
#     822 host, port = address
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#     826     sock = None
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     952 # We override this function since we want to translate the numeric family
#     953 # and socket type values to enum constants.
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#     957     addrlist.append((_intenum_converter(af, AddressFamily),
#     958                      _intenum_converter(socktype, SocketKind),
#     959                      proto, canonname, sa))
#
# KeyboardInterrupt:
